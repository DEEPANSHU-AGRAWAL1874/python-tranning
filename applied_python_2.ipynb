# %%
import pandas as pd 
import numpy as np

# %%
weather = pd.read_csv("C:/Users/Sai/OneDrive/Desktop/austin_weather.csv")
titanic = pd.read_csv("C:/Users/Sai/OneDrive/Desktop/Titanic Dataset.csv")

# %%
weather.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
weather[["Date","TempAvgF",'Events']]
# Out:
#             Date  TempAvgF               Events
# 0     2013-12-21        60  Rain , Thunderstorm
# 1     2013-12-22        48
# 2     2013-12-23        45
# 3     2013-12-24        46
# 4     2013-12-25        50
# ...          ...       ...                  ...
# 1314  2017-07-27        89
# 1315  2017-07-28        91
# 1316  2017-07-29        92
# 1317  2017-07-30        93
# 1318  2017-07-31        88
#
# [1319 rows x 3 columns]

# %%
# giving the index 
titanic.iloc[5]
# Out:
# PassengerId                           897
# Survived                                0
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
titanic.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# fancing indexing
titanic.iloc[[0,4,5,18,45,100]]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 4            896         1       3
# 5            897         0       3
# 18           910         1       3
# 45           937         0       3
# 100          992         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                     Kelly, Mr. James    male  34.5      0
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                           Svensson, Mr. Johan Cervin    male  14.0      0
# 18                        Ilmakangas, Miss. Ida Livija  female  27.0      1
# 45                     Peltomaki, Mr. Nikolai Johannes    male  25.0      0
# 100  Stengel, Mrs. Charles Emil Henry (Annie May Mo...  female  43.0      1
#
#      Parch             Ticket     Fare Cabin Embarked
# 0        0             330911   7.8292   NaN        Q
# 4        1            3101298  12.2875   NaN        S
# ...

# %%
titanic.loc[[1,2,41,3]]
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894         0       2         Myles, Mr. Thomas Francis    male
# 41          933         0       1       Franklin, Mr. Thomas Parham    male
# 3           895         0       3                  Wirz, Mr. Albert    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 1   47.0      1      0  363272   7.0000   NaN        S
# 2   62.0      0      0  240276   9.6875   NaN        Q
# 41   NaN      0      0  113778  26.5500   D34        S
# 3   27.0      0      0  315154   8.6625   NaN        S

# %%
# difference between iloc and loc

# %%
titanic.iloc[0:3,0:6]
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age
# 0  34.5
# 1  47.0
# 2  62.0

# %%
titanic.loc[0:3,"PassengerId":'Age']
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age
# 0  34.5
# 1  47.0
# 2  62.0
# 3  27.0

# %%
titanic.info()
titanic['Age'] = titanic['Age'].astype('float32')
titanic['Sex'] = titanic['Sex'].astype('category')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    category
#  5   Age          332 non-null    float32
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: category(1), float32(1), float64(1), int64(5), object(4)
# memory usage: 34.9+ KB

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
(((titanic['Age'] >=40) & (titanic['Sex'] == 'male')).value_counts())
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
(((weather['TempAvgF']>30)& (weather['Events'] == 'Rain')).value_counts())
# Out:
# False    1128
# True      191
# Name: count, dtype: int64

# %%
print(titanic.sort_values('PassengerId'))
titanic.sort_values('PassengerId', ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
New_data = pd.DataFrame({
        'name':['Aniket','Rupali','Anjali',np.nan,'Malay',np.nan,'Mona',np.nan,'Mishra ji',np.nan],
        'college':['bits','IIT','VIT',np.nan,np.nan,'VIT','DAVV',np.nan,np.nan,'LPU'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]}
)

New_data
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 1     Rupali     IIT     it   8.25      5.0
# 2     Anjali     VIT    cse   6.41      6.0
# 3        NaN     NaN    NaN    NaN      NaN
# 4      Malay     NaN     me   5.60      6.0
# 5        NaN     VIT     ce   9.00      7.0
# 6       Mona    DAVV    civ   7.40      8.0
# 7        NaN     NaN    cse  10.00      9.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 9        NaN     LPU    NaN    NaN      NaN

# %%
x = New_data.sort_values('name',na_position= 'first')
x
# Out:
#         name college branch   cgpa  package
# 3        NaN     NaN    NaN    NaN      NaN
# 5        NaN     VIT     ce   9.00      7.0
# 7        NaN     NaN    cse  10.00      9.0
# 9        NaN     LPU    NaN    NaN      NaN
# 0     Aniket    bits    eee   6.66      4.0
# 2     Anjali     VIT    cse   6.41      6.0
# 4      Malay     NaN     me   5.60      6.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 6       Mona    DAVV    civ   7.40      8.0
# 1     Rupali     IIT     it   8.25      5.0

# %%
titanic.sort_values(['Pclass', 'Name'], ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass  \
# 371         1263         1       1
# 23           915         0       1
# 231         1123         1       1
# 218         1110         1       1
# 407         1299         0       1
# ..           ...       ...     ...
# 8            900         1       3
# 251         1143         0       3
# 57           949         0       3
# 345         1237         1       3
# 392         1284         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 371                     Wilson, Miss. Helen Alice  female  31.0      0      0
# 23                Williams, Mr. Richard Norris II    male  21.0      0      1
# 231                      Willard, Miss. Constance  female  21.0      0      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
# ...

# %%
titanic.set_index('PassengerId', inplace = True)

# %%
titanic.sample(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1021                0       3
# 895                 0       3
# 936                 1       1
# 1025                0       3
# 1221                0       2
# 1030                1       3
# 979                 1       3
# 1126                0       1
# 1043                0       3
# 1079                0       3
#
#                                                          Name     Sex   Age  \
# PassengerId
# 1021                                     Petersen, Mr. Marius    male  24.0
# 895                                          Wirz, Mr. Albert    male  27.0
# 936          Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)  female  45.0
# 1025                                    Thomas, Mr. Charles P    male   NaN
# 1221                                      Enander, Mr. Ingvar    male  21.0
# 1030                                    Drapkin, Miss. Jennie  female  23.0
# ...

# %%
titanic.reset_index(inplace= True)

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 175         1067         1       2
# 206         1098         1       3
# 4            896         1       3
# 103          995         0       3
# 303         1195         0       3
# 150         1042         1       1
# 153         1045         1       3
# 57           949         0       3
# 94           986         0       1
# 290         1182         0       1
#
#                                                Name     Sex   Age  SibSp  \
# 175                       Brown, Miss. Edith Eileen  female  15.0      0
# 206                        McGowan, Miss. Katherine  female  35.0      0
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 103          Johansson Palmquist, Mr. Oskar Leander    male  26.0      0
# 303                               Pokrnic, Mr. Tome    male  24.0      0
# 150           Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# ...

# %%
New_data['name'].fillna('------')
# Out:
# 0       Aniket
# 1       Rupali
# 2       Anjali
# 3       ------
# 4        Malay
# 5       ------
# 6         Mona
# 7       ------
# 8    Mishra ji
# 9       ------
# Name: name, dtype: object

# %%
New_data
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 1     Rupali     IIT     it   8.25      5.0
# 2     Anjali     VIT    cse   6.41      6.0
# 3        NaN     NaN    NaN    NaN      NaN
# 4      Malay     NaN     me   5.60      6.0
# 5        NaN     VIT     ce   9.00      7.0
# 6       Mona    DAVV    civ   7.40      8.0
# 7        NaN     NaN    cse  10.00      9.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 9        NaN     LPU    NaN    NaN      NaN

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 148         1040         0       1
# 374         1266         1       1
# 70           962         1       3
# 132         1024         1       3
# 218         1110         1       1
# 182         1074         1       1
# 180         1072         0       2
# 156         1048         1       1
# 181         1073         0       1
# 362         1254         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 148                          Crafton, Mr. John Bertram    male   NaN      0
# 374              Dodge, Mrs. Washington (Ruth Vidaver)  female  54.0      1
# 70                           Mulvihill, Miss. Bertha E  female  24.0      0
# 132                      Lefebre, Mrs. Frank (Frances)  female   NaN      0
# 218       Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1
# 182  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...  female  18.0      1
# ...

# %%
a = titanic[((titanic['Fare'] > 100) & (titanic['Age'] < 30))]
name = a['Name']
name
# Out:
# 53                            Fortune, Miss. Ethel Flora
# 64                           Ryerson, Master. John Borie
# 156                                    Bird, Miss. Ellen
# 184    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 196                      Spedden, Master. Robert Douglas
# 252                             Clark, Mr. Walter Miller
# 272        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object

# %%
titanic['PassengerId'].unique()
# Out:
# array([ 892,  893,  894,  895,  896,  897,  898,  899,  900,  901,  902,
#         903,  904,  905,  906,  907,  908,  909,  910,  911,  912,  913,
#         914,  915,  916,  917,  918,  919,  920,  921,  922,  923,  924,
#         925,  926,  927,  928,  929,  930,  931,  932,  933,  934,  935,
#         936,  937,  938,  939,  940,  941,  942,  943,  944,  945,  946,
#         947,  948,  949,  950,  951,  952,  953,  954,  955,  956,  957,
#         958,  959,  960,  961,  962,  963,  964,  965,  966,  967,  968,
#         969,  970,  971,  972,  973,  974,  975,  976,  977,  978,  979,
#         980,  981,  982,  983,  984,  985,  986,  987,  988,  989,  990,
#         991,  992,  993,  994,  995,  996,  997,  998,  999, 1000, 1001,
#        1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012,
#        1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023,
#        1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034,
# ...

# %%
titanic['Pclass'].nunique()
# Out:
# 3

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
New_data
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 1     Rupali     IIT     it   8.25      5.0
# 2     Anjali     VIT    cse   6.41      6.0
# 3        NaN     NaN    NaN    NaN      NaN
# 4      Malay     NaN     me   5.60      6.0
# 5        NaN     VIT     ce   9.00      7.0
# 6       Mona    DAVV    civ   7.40      8.0
# 7        NaN     NaN    cse  10.00      9.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 9        NaN     LPU    NaN    NaN      NaN

# %%
a = New_data.isnull().sum()
a
# Out:
# name       4
# college    4
# branch     2
# cgpa       2
# package    3
# dtype: int64

# %%
New_data[New_data['name'].isnull() | (New_data['college'].isnull()  ) | New_data['branch'].isnull() | New_data['cgpa'].isnull()]
# Out:
#         name college branch  cgpa  package
# 3        NaN     NaN    NaN   NaN      NaN
# 4      Malay     NaN     me   5.6      6.0
# 5        NaN     VIT     ce   9.0      7.0
# 7        NaN     NaN    cse  10.0      9.0
# 8  Mishra ji     NaN    bio   7.4      NaN
# 9        NaN     LPU    NaN   NaN      NaN

# %%
New_data['name'] = New_data['name'].fillna('--------')
New_data
# Out:
#         name college branch   cgpa  package
# 0     Aniket    bits    eee   6.66      4.0
# 1     Rupali     IIT     it   8.25      5.0
# 2     Anjali     VIT    cse   6.41      6.0
# 3   --------     NaN    NaN    NaN      NaN
# 4      Malay     NaN     me   5.60      6.0
# 5   --------     VIT     ce   9.00      7.0
# 6       Mona    DAVV    civ   7.40      8.0
# 7   --------     NaN    cse  10.00      9.0
# 8  Mishra ji     NaN    bio   7.40      NaN
# 9   --------     LPU    NaN    NaN      NaN

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
a = titanic[((titanic['Fare'] > 100) & (titanic['Age'] < 30))]
name = a['Name']
name
# Out:
# 53                            Fortune, Miss. Ethel Flora
# 64                           Ryerson, Master. John Borie
# 156                                    Bird, Miss. Ellen
# 184    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 196                      Spedden, Master. Robert Douglas
# 252                             Clark, Mr. Walter Miller
# 272        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object

# %%
#2
a = titanic.sort_values('Age',ascending= False) 
b = a.sort_values('Survived',ascending=False)
b.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 282         1174         1       3
# 273         1165         1       3
# 268         1160         1       3
# 391         1283         1       1
# 224         1116         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 282                             Fleming, Miss. Honora  female   NaN      0
# 273                                Lennon, Miss. Mary  female   NaN      1
# 268                       Howard, Miss. May Elizabeth  female   NaN      0
# 391    Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female  51.0      0
# 224  Candee, Mrs. Edward (Helen Churchill Hungerford)  female  53.0      0
#
#      Parch       Ticket     Fare Cabin Embarked Title
# 282      0       364859   7.7500   NaN        Q   Mrs
# 273      0       370371  15.5000   NaN        Q   Mrs
# 268      0  A. 2. 39186   8.0500   NaN        S   Mrs
# 391      1     PC 17592  39.4000   D28        S   Mrs
# ...

# %%
titanic['Cabin'].isnull().sum()
# Out:
# np.int64(327)

# %%
a = titanic['Age'].isnull().sum()
print(a)
titanic['Age'].fillna(titanic['Age'].mean())
# Out:
# 86
# 0      34.500000
# 1      47.000000
# 2      62.000000
# 3      27.000000
# 4      22.000000
#          ...
# 413    30.272591
# 414    39.000000
# 415    38.500000
# 416    30.272591
# 417    30.272591
# Name: Age, Length: 418, dtype: float32

# %%
titanic['Title'] = np.where(titanic['Sex'] == 'Male' ,'Mr','Mrs')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
a = titanic.sort_values('Fare', ascending= False)
a.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 69           961         1       1
# 53           945         1       1
# 59           951         1       1
# 64           956         0       1
# 375         1267         1       1
# 142         1034         0       1
# 24           916         1       1
# 184         1076         1       1
# 202         1094         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 375                           Bowen, Miss. Grace Scott  female  45.0      0
# ...

# %%
a = titanic.sort_values('Age')
b = a.sort_values('Survived')

b['Name'].head(1)
# Out:
# 360    Sage, Master. William Henry
# Name: Name, dtype: object

# %%
titanic[titanic['Name'].str.startswith('A')][:5]
# Out:
#     PassengerId  Survived  Pclass                                       Name  \
# 8           900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 17          909         0       3                          Assaf, Mr. Gerios
# 19          911         1       3      Assaf Khalil, Mrs. Mariana (Miriam")"
# 57          949         0       3              Abelseth, Mr. Olaus Jorgensen
# 78          970         0       2             Aldworth, Mr. Charles Augustus
#
#        Sex   Age  SibSp  Parch  Ticket     Fare  Cabin Embarked Title
# 8   female  18.0      0      0    2657   7.2292    NaN        C   Mrs
# 17    male  21.0      0      0    2692   7.2250    NaN        C   Mrs
# 19  female  45.0      0      0    2696   7.2250    NaN        C   Mrs
# 57    male  25.0      0      0  348122   7.6500  F G63        S   Mrs
# 78    male  30.0      0      0  248744  13.0000    NaN        S   Mrs

# %%
titanic['Familysiz'] = titanic['SibSp'] + titanic['Parch']
a =titanic[titanic['Familysiz'] > 3]
a[0:10]
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 53           945         1       1
# 55           947         0       3
# 64           956         0       1
# 69           961         1       1
# 132         1024         1       3
# 139         1031         0       3
# 140         1032         1       3
# 142         1034         0       1
# 154         1046         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 24   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 53                        Fortune, Miss. Ethel Flora  female  28.0      3
# 55                              Rice, Master. Albert    male  10.0      4
# 64                       Ryerson, Master. John Borie    male  13.0      2
# 69               Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 132                    Lefebre, Mrs. Frank (Frances)  female   NaN      0
# ...

# %%
titanic['Fareperperson'] = (titanic['SibSp'] + titanic['Parch'] +1)/titanic['Fare']
a = titanic.sort_values('Fareperperson',ascending= False)
a
# Out:
#      PassengerId  Survived  Pclass  \
# 266         1158         0       1
# 372         1264         0       1
# 214         1106         1       3
# 21           913         0       3
# 337         1229         0       3
# ..           ...       ...     ...
# 156         1048         1       1
# 343         1235         1       1
# 59           951         1       1
# 375         1267         1       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 266              Chisholm, Mr. Roderick Robert Crispin    male   NaN      0
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 214             Andersson, Miss. Ida Augusta Margareta  female  38.0      4
# 21                           Olsen, Master. Artur Karl    male   9.0      0
# 337                                  Elias, Mr. Joseph    male  39.0      0
# ..                                                 ...     ...   ...    ...
# ...
